# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
df=pd.read_csv('/workspaces/HeartDiseaseAI/heart disease/train.csv')
df
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0            0   58    1                4  152          239             0
# 1            1   52    1                1  125          325             0
# 2            2   56    0                2  160          188             0
# 3            3   44    0                3  134          229             0
# 4            4   58    1                4  140          234             0
# ...        ...  ...  ...              ...  ...          ...           ...
# 629995  629995   56    0                1  110          226             0
# 629996  629996   54    1                4  128          249             1
# 629997  629997   67    1                4  130          275             0
# 629998  629998   52    1                4  140          199             0
# 629999  629999   51    0                2  130          199             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0                 0     158                1            3.6            2
# 1                 2     171                0            0.0            1
# 2                 2     151                0            0.0            1
# 3                 2     150                0            1.0            2
# 4                 2     125                1            3.8            2
# ...             ...     ...              ...            ...          ...
# 629995            0     132                0            0.0            1
# 629996            2     150                0            0.0            2
# 629997            0     149                0            0.0            1
# 629998            2     157                0            0.0            1
# 629999            0     168                0            0.0            1
#
#         Number of vessels fluro  Thallium Heart Disease
# 0                             2         7      Presence
# 1                             0         3       Absence
# 2                             0         3       Absence
# 3                             0         3       Absence
# 4                             3         3      Presence
# ...                         ...       ...           ...
# 629995                        0         7       Absence
# 629996                        0         3       Absence
# 629997                        2         7      Presence
# 629998                        0         6      Presence
# 629999                        0         3       Absence
#
# [630000 rows x 15 columns]

# %%
df.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# 2                        0         3       Absence
# 3                        0         3       Absence
# 4                        3         3      Presence

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Age                      630000 non-null  int64
#  2   Sex                      630000 non-null  int64
#  3   Chest pain type          630000 non-null  int64
#  4   BP                       630000 non-null  int64
#  5   Cholesterol              630000 non-null  int64
#  6   FBS over 120             630000 non-null  int64
#  7   EKG results              630000 non-null  int64
#  8   Max HR                   630000 non-null  int64
#  9   Exercise angina          630000 non-null  int64
#  10  ST depression            630000 non-null  float64
#  11  Slope of ST              630000 non-null  int64
#  12  Number of vessels fluro  630000 non-null  int64
#  13  Thallium                 630000 non-null  int64
#  14  Heart Disease            630000 non-null  str
# dtypes: float64(1), int64(13), str(1)
# memory usage: 72.1 MB

# %%
df.shape
# Out:
# (630000, 15)

# %%
df.columns
# Out:
# Index(['id', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol',
#        'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina',
#        'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium',
#        'Heart Disease'],
#       dtype='str')

# %%
df.describe()
# Out:
#                   id            Age            Sex  Chest pain type  \
# count  630000.000000  630000.000000  630000.000000    630000.000000
# mean   314999.500000      54.136706       0.714735         3.312752
# std    181865.479132       8.256301       0.451541         0.851615
# min         0.000000      29.000000       0.000000         1.000000
# 25%    157499.750000      48.000000       0.000000         3.000000
# 50%    314999.500000      54.000000       1.000000         4.000000
# 75%    472499.250000      60.000000       1.000000         4.000000
# max    629999.000000      77.000000       1.000000         4.000000
#
#                   BP    Cholesterol   FBS over 120    EKG results  \
# count  630000.000000  630000.000000  630000.000000  630000.000000
# mean      130.497433     245.011814       0.079987       0.981660
# std        14.975802      33.681581       0.271274       0.998783
# min        94.000000     126.000000       0.000000       0.000000
# 25%       120.000000     223.000000       0.000000       0.000000
# 50%       130.000000     243.000000       0.000000       0.000000
# 75%       140.000000     269.000000       0.000000       2.000000
# max       200.000000     564.000000       1.000000       2.000000
#
#               Max HR  Exercise angina  ST depression    Slope of ST  \
# count  630000.000000    630000.000000  630000.000000  630000.000000
# mean      152.816763         0.273725       0.716028       1.455871
# std        19.112927         0.445870       0.948472       0.545192
# min        71.000000         0.000000       0.000000       1.000000
# 25%       142.000000         0.000000       0.000000       1.000000
# 50%       157.000000         0.000000       0.100000       1.000000
# 75%       166.000000         1.000000       1.400000       2.000000
# max       202.000000         1.000000       6.200000       3.000000
#
#        Number of vessels fluro       Thallium
# count            630000.000000  630000.000000
# mean                  0.451040       4.618873
# std                   0.798549       1.950007
# min                   0.000000       3.000000
# 25%                   0.000000       3.000000
# 50%                   0.000000       3.000000
# 75%                   1.000000       7.000000
# max                   3.000000       7.000000

# %%
df.isnull().sum()
# Out:
# id                         0
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df.dtypes
# Out:
# id                           int64
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease                  str
# dtype: object

# %%
id=df['id']
id
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 629995    629995
# 629996    629996
# 629997    629997
# 629998    629998
# 629999    629999
# Name: id, Length: 630000, dtype: int64

# %%
df = df.drop('id', axis=1)
df
# Out:
#         Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0        58    1                4  152          239             0
# 1        52    1                1  125          325             0
# 2        56    0                2  160          188             0
# 3        44    0                3  134          229             0
# 4        58    1                4  140          234             0
# ...     ...  ...              ...  ...          ...           ...
# 629995   56    0                1  110          226             0
# 629996   54    1                4  128          249             1
# 629997   67    1                4  130          275             0
# 629998   52    1                4  140          199             0
# 629999   51    0                2  130          199             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0                 0     158                1            3.6            2
# 1                 2     171                0            0.0            1
# 2                 2     151                0            0.0            1
# 3                 2     150                0            1.0            2
# 4                 2     125                1            3.8            2
# ...             ...     ...              ...            ...          ...
# 629995            0     132                0            0.0            1
# 629996            2     150                0            0.0            2
# 629997            0     149                0            0.0            1
# 629998            2     157                0            0.0            1
# 629999            0     168                0            0.0            1
#
#         Number of vessels fluro  Thallium Heart Disease
# 0                             2         7      Presence
# 1                             0         3       Absence
# 2                             0         3       Absence
# 3                             0         3       Absence
# 4                             3         3      Presence
# ...                         ...       ...           ...
# 629995                        0         7       Absence
# 629996                        0         3       Absence
# 629997                        2         7      Presence
# 629998                        0         6      Presence
# 629999                        0         3       Absence
#
# [630000 rows x 14 columns]

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   58    1                4  152          239             0            0
# 1   52    1                1  125          325             0            2
# 2   56    0                2  160          188             0            2
# 3   44    0                3  134          229             0            2
# 4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# 2                        0         3       Absence
# 3                        0         3       Absence
# 4                        3         3      Presence

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      630000 non-null  int64
#  1   Sex                      630000 non-null  int64
#  2   Chest pain type          630000 non-null  int64
#  3   BP                       630000 non-null  int64
#  4   Cholesterol              630000 non-null  int64
#  5   FBS over 120             630000 non-null  int64
#  6   EKG results              630000 non-null  int64
#  7   Max HR                   630000 non-null  int64
#  8   Exercise angina          630000 non-null  int64
#  9   ST depression            630000 non-null  float64
#  10  Slope of ST              630000 non-null  int64
#  11  Number of vessels fluro  630000 non-null  int64
#  12  Thallium                 630000 non-null  int64
#  13  Heart Disease            630000 non-null  str
# dtypes: float64(1), int64(12), str(1)
# memory usage: 67.3 MB

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease                  str
# dtype: object

# %%
df["Heart Disease"].unique()
# Out:
# <StringArray>
# ['Presence', 'Absence']
# Length: 2, dtype: str

# %%
df['Heart Disease'] = df['Heart Disease'].map({
    'Absence': 0,
    'Presence': 1
})

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease                int64
# dtype: object

# %%
print(df['Heart Disease']. value_counts())
print(f"The difference between 347546 and 282454 is {347546 - 282454}")
# Out:
# Heart Disease
# 0    347546
# 1    282454
# Name: count, dtype: int64
# The difference between 347546 and 282454 is 65092

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
X = df.drop('Heart Disease', axis=1)
y = df['Heart Disease']

# %%
print(X.shape)
print(y.shape)
# Out:
# (630000, 13)
# (630000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (504000, 13)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-02-24 05:36:42.479925: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,801 (50.00 KB)
#  Trainable params: 12,801 (50.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=70,batch_size=30,validation_split=0.2)
# Out:
# Epoch 1/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8767 - loss: 0.3051 - val_accuracy: 0.8861 - val_loss: 0.2775
# Epoch 2/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8773 - loss: 0.3042 - val_accuracy: 0.8859 - val_loss: 0.2767
# Epoch 3/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8770 - loss: 0.3047 - val_accuracy: 0.8866 - val_loss: 0.2773
# Epoch 4/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8775 - loss: 0.3039 - val_accuracy: 0.8860 - val_loss: 0.2762
# Epoch 5/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8777 - loss: 0.3034 - val_accuracy: 0.8860 - val_loss: 0.2781
# Epoch 6/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8770 - loss: 0.3031 - val_accuracy: 0.8861 - val_loss: 0.2788
# Epoch 7/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8771 - loss: 0.3038 - val_accuracy: 0.8862 - val_loss: 0.2783
# Epoch 8/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8777 - loss: 0.3033 - val_accuracy: 0.8863 - val_loss: 0.2779
# Epoch 9/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8777 - loss: 0.3032 - val_accuracy: 0.8862 - val_loss: 0.2775
# Epoch 10/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8778 - loss: 0.3036 - val_accuracy: 0.8862 - val_loss: 0.2782
# Epoch 11/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8778 - loss: 0.3030 - val_accuracy: 0.8860 - val_loss: 0.2791
# Epoch 12/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8778 - loss: 0.3023 - val_accuracy: 0.8851 - val_loss: 0.2787
# Epoch 13/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8778 - loss: 0.3024 - val_accuracy: 0.8855 - val_loss: 0.2784
# Epoch 14/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8778 - loss: 0.3027 - val_accuracy: 0.8862 - val_loss: 0.2794
# Epoch 15/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8779 - loss: 0.3025 - val_accuracy: 0.8860 - val_loss: 0.2777
# Epoch 16/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3032 - val_accuracy: 0.8858 - val_loss: 0.2773
# Epoch 17/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8780 - loss: 0.3023 - val_accuracy: 0.8858 - val_loss: 0.2775
# Epoch 18/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - accuracy: 0.8783 - loss: 0.3021 - val_accuracy: 0.8855 - val_loss: 0.2782
# Epoch 19/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8781 - loss: 0.3027 - val_accuracy: 0.8855 - val_loss: 0.2778
# Epoch 20/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8780 - loss: 0.3022 - val_accuracy: 0.8860 - val_loss: 0.2789
# Epoch 21/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8777 - loss: 0.3030 - val_accuracy: 0.8855 - val_loss: 0.2783
# Epoch 22/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3026 - val_accuracy: 0.8859 - val_loss: 0.2786
# Epoch 23/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8780 - loss: 0.3021 - val_accuracy: 0.8856 - val_loss: 0.2783
# Epoch 24/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8779 - loss: 0.3025 - val_accuracy: 0.8861 - val_loss: 0.2786
# Epoch 25/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8780 - loss: 0.3019 - val_accuracy: 0.8857 - val_loss: 0.2782
# Epoch 26/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3020 - val_accuracy: 0.8855 - val_loss: 0.2794
# Epoch 27/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3016 - val_accuracy: 0.8856 - val_loss: 0.2792
# Epoch 28/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8779 - loss: 0.3023 - val_accuracy: 0.8854 - val_loss: 0.2805
# Epoch 29/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3017 - val_accuracy: 0.8858 - val_loss: 0.2785
# Epoch 30/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8782 - loss: 0.3019 - val_accuracy: 0.8856 - val_loss: 0.2780
# Epoch 31/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8779 - loss: 0.3016 - val_accuracy: 0.8857 - val_loss: 0.2776
# Epoch 32/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8779 - loss: 0.3021 - val_accuracy: 0.8858 - val_loss: 0.2807
# Epoch 33/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3018 - val_accuracy: 0.8862 - val_loss: 0.2801
# Epoch 34/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8783 - loss: 0.3022 - val_accuracy: 0.8857 - val_loss: 0.2776
# Epoch 35/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8783 - loss: 0.3017 - val_accuracy: 0.8853 - val_loss: 0.2783
# Epoch 36/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8786 - loss: 0.3016 - val_accuracy: 0.8858 - val_loss: 0.2803
# Epoch 37/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8782 - loss: 0.3020 - val_accuracy: 0.8861 - val_loss: 0.2801
# Epoch 38/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8781 - loss: 0.3013 - val_accuracy: 0.8856 - val_loss: 0.2814
# Epoch 39/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8782 - loss: 0.3017 - val_accuracy: 0.8859 - val_loss: 0.2795
# Epoch 40/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3015 - val_accuracy: 0.8861 - val_loss: 0.2790
# Epoch 41/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8787 - loss: 0.3012 - val_accuracy: 0.8858 - val_loss: 0.2783
# Epoch 42/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3010 - val_accuracy: 0.8862 - val_loss: 0.2801
# Epoch 43/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8783 - loss: 0.3009 - val_accuracy: 0.8859 - val_loss: 0.2798
# Epoch 44/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8787 - loss: 0.3009 - val_accuracy: 0.8857 - val_loss: 0.2809
# Epoch 45/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 42s 2ms/step - accuracy: 0.8780 - loss: 0.3014 - val_accuracy: 0.8856 - val_loss: 0.2830
# Epoch 46/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.8784 - loss: 0.3009 - val_accuracy: 0.8857 - val_loss: 0.2793
# Epoch 47/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8784 - loss: 0.3008 - val_accuracy: 0.8856 - val_loss: 0.2844
# Epoch 48/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8782 - loss: 0.3013 - val_accuracy: 0.8856 - val_loss: 0.2805
# Epoch 49/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8782 - loss: 0.3019 - val_accuracy: 0.8855 - val_loss: 0.2812
# Epoch 50/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3009 - val_accuracy: 0.8852 - val_loss: 0.2809
# Epoch 51/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8787 - loss: 0.3010 - val_accuracy: 0.8853 - val_loss: 0.2827
# Epoch 52/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8781 - loss: 0.3018 - val_accuracy: 0.8855 - val_loss: 0.2793
# Epoch 53/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8781 - loss: 0.3018 - val_accuracy: 0.8857 - val_loss: 0.2803
# Epoch 54/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8782 - loss: 0.3005 - val_accuracy: 0.8853 - val_loss: 0.2834
# Epoch 55/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8787 - loss: 0.3007 - val_accuracy: 0.8857 - val_loss: 0.2820
# Epoch 56/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8785 - loss: 0.3014 - val_accuracy: 0.8859 - val_loss: 0.2801
# Epoch 57/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 23s 2ms/step - accuracy: 0.8786 - loss: 0.3011 - val_accuracy: 0.8854 - val_loss: 0.2800
# Epoch 58/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8788 - loss: 0.3007 - val_accuracy: 0.8855 - val_loss: 0.2839
# Epoch 59/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8787 - loss: 0.3013 - val_accuracy: 0.8855 - val_loss: 0.2805
# Epoch 60/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8784 - loss: 0.3013 - val_accuracy: 0.8851 - val_loss: 0.2824
# Epoch 61/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3010 - val_accuracy: 0.8855 - val_loss: 0.2811
# Epoch 62/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3010 - val_accuracy: 0.8855 - val_loss: 0.2835
# Epoch 63/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8784 - loss: 0.3008 - val_accuracy: 0.8852 - val_loss: 0.2822
# Epoch 64/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8785 - loss: 0.3007 - val_accuracy: 0.8852 - val_loss: 0.2814
# Epoch 65/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8786 - loss: 0.3005 - val_accuracy: 0.8858 - val_loss: 0.2825
# Epoch 66/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - accuracy: 0.8790 - loss: 0.3008 - val_accuracy: 0.8846 - val_loss: 0.2848
# Epoch 67/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3008 - val_accuracy: 0.8855 - val_loss: 0.2813
# Epoch 68/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8781 - loss: 0.3013 - val_accuracy: 0.8852 - val_loss: 0.2831
# Epoch 69/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8783 - loss: 0.3011 - val_accuracy: 0.8857 - val_loss: 0.2821
# Epoch 70/70
# 13440/13440 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step - accuracy: 0.8786 - loss: 0.3009 - val_accuracy: 0.8854 - val_loss: 0.2818

# %%
his = history.history
print(his.keys())
print(his['accuracy'])
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# [0.8767262101173401, 0.8773065209388733, 0.8770089149475098, 0.8774950504302979, 0.8776736259460449, 0.8769890666007996, 0.8771205544471741, 0.877723217010498, 0.8777182698249817, 0.8778001070022583, 0.8778075575828552, 0.8777579069137573, 0.8777976036071777, 0.8778471946716309, 0.8778819441795349, 0.8781200647354126, 0.8780282735824585, 0.8782663941383362, 0.8781448602676392, 0.8780133724212646, 0.877666175365448, 0.8781423568725586, 0.8779786825180054, 0.8778794407844543, 0.877996027469635, 0.878325879573822, 0.8781026601791382, 0.8778844475746155, 0.8781026601791382, 0.8782415390014648, 0.8778720498085022, 0.8778794407844543, 0.8782812356948853, 0.878268837928772, 0.8782787919044495, 0.8786160945892334, 0.8781647086143494, 0.8781026601791382, 0.878204345703125, 0.8780853152275085, 0.8787251710891724, 0.8781101107597351, 0.8783060312271118, 0.8786656856536865, 0.8780357241630554, 0.8784226179122925, 0.8784399628639221, 0.8782068490982056, 0.8782217502593994, 0.8782539963722229, 0.8787127733230591, 0.8780803680419922, 0.8781299591064453, 0.8781647086143494, 0.878663182258606, 0.878534197807312, 0.8785862922668457, 0.87884920835495, 0.8787326216697693, 0.878447413444519, 0.8782961368560791, 0.878333330154419, 0.8783754706382751, 0.8785367012023926, 0.8785962462425232, 0.8789781928062439, 0.878268837928772, 0.8781150579452515, 0.8782514929771423, 0.8786011934280396]

# %%
his['val_accuracy'][-1]
# Out:
# 0.885357141494751

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)
# Out:
# 3938/3938 ━━━━━━━━━━━━━━━━━━━━ 3s 731us/step

# %%
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8843730158730159

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     69397
#            1       0.88      0.86      0.87     56603
#
#     accuracy                           0.88    126000
#    macro avg       0.88      0.88      0.88    126000
# weighted avg       0.88      0.88      0.88    126000

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[62709  6688]
#  [ 7881 48722]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues',
            xticklabels=["No Disease","Disease"],
            yticklabels=["No Disease","Disease"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("ANN Confusion Matrix")
plt.show()

# %%
model.save("ann_model.keras")

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model("ann_model.keras")
